# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
plt.style.use('dark_background')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Any missing data to be picked up as "False"

# %%
df.notna()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# ...

# %% [markdown]
# dropping rows with any missing content (notice how the row size shrinks from 891 to 183)

# %%
df=df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Different types of Cabins

# %%
List_of_Cabin=[]
for x in np.array(df['Cabin']):
    if x not in List_of_Cabin:
         List_of_Cabin.append(x)
a=np.array(List_of_Cabin)
np.array(a.reshape(1,-1)).flatten()
# Out:
# array(['nan', 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %% [markdown]
# Starting off with single feature logistic regresion...

# %%
x_train = np.array(df["Age"]).reshape(-1,1)
y_train = np.array(df["Survived"])

# %%
from numpy import c_
a=[0,1,2]
b=[3,4,5]
c=np.c_[a,b]
c
# Out:
# array([[0, 3],
#        [1, 4],
#        [2, 5]])

# %%
c.shape
# Out:
# (3, 2)

# %%
 d=np.array([[[ 1,  2,  3],
         [ 1,  2,  3]],

         [[12,  3,  4],
         [ 2,  1,  3]]])
 d.shape
# Out:
# (2, 2, 3)

# %% [markdown]
# Counting % of survivors to see any sign of skewedness:

# %%
n=np.size(y_train)
survived=0
for i in range(n):
    if y_train[i]==1:
        survived=survived+1
print("Percentage of those survived: {} %".format((survived/n)*100))
# Out:
# Percentage of those survived: 38.38383838383838 %

# %% [markdown]
# Plotting the data to see if it follows Log Reg pattern (doesn't look like it?...)

# %%
plt.scatter(x_train,y_train,color='red', alpha=0.5)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-4719cf73997a> in <module>
# ----> 1 model.fit(x_train,y_train)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1340             _dtype = [np.float64, np.float32]
#    1341
# -> 1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...
